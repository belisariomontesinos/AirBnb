# %% [markdown]
# ## Air Bnb Capstone ##

# %% [markdown]
# ### Can I buy a property that pays for itself in NYC? ###

# %% [markdown]
# Import Packages

# %%
import pandas as pd
import numpy as np
import seaborn as sns
from matplotlib import pyplot as plt
from matplotlib import patches as mpatches

# %% [markdown]
# Assign data

# %%
lst = pd.read_csv('~/Downloads/listings.csv', delimiter = ',', header = 0)
#cal = pd.read_csv('~/Downloads/listings.csv.gz', delimiter = ',', header = 0)
rev = pd.read_csv('~/Downloads/reviews.csv', delimiter = ',', header = 0)
hood = pd.read_csv('~/Downloads/neighbourhoods.csv', delimiter = ',', header = 0)
# Out:
# /Users/belisariomontesinos/miniconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3072: DtypeWarning: Columns (61,62,94) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %% [markdown]
# Get a feel for the data

# %%
rev.head(2)
# Out:
#    listing_id     id        date  reviewer_id reviewer_name  \
# 0        2060    158  2008-09-22         2865          Thom
# 1        2595  17857  2009-11-21        50679          Jean
#
#                                             comments
# 0  very nice neighborhood,close enough to "A" tra...
# 1  Notre séjour de trois nuits.\r\nNous avons app...

# %%
lst.head(2)
# Out:
#      id                        listing_url       scrape_id last_scraped  \
# 0  2060  https://www.airbnb.com/rooms/2060  20200707031313   2020-07-08
# 1  2595  https://www.airbnb.com/rooms/2595  20200707031313   2020-07-08
#
#                     name                                            summary  \
# 0             Modern NYC                                                NaN
# 1  Skylit Midtown Castle  Beautiful, spacious skylit studio in the heart...
#
#                                                space  \
# 0  Lovely, spacious, sunny 1 BR apartment in 6th ...
# 1  - Spacious (500+ft²), immaculate and nicely fu...
#
#                                          description experiences_offered  \
# 0  Lovely, spacious, sunny 1 BR apartment in 6th ...                none
# 1  Beautiful, spacious skylit studio in the heart...                none
#
#                                neighborhood_overview  ... instant_bookable  \
# 0                                                NaN  ...                f
# 1  Centrally located in the heart of Manhattan ju...  ...                f
#
#   is_business_travel_ready          cancellation_policy  \
# 0                        f                     flexible
# 1                        f  strict_14_with_grace_period
#
#   require_guest_profile_picture require_guest_phone_verification  \
# 0                             f                                f
# 1                             t                                t
#
#    calculated_host_listings_count  \
# 0                               1
# 1                               2
#
#    calculated_host_listings_count_entire_homes  \
# 0                                            0
# 1                                            2
#
#   calculated_host_listings_count_private_rooms  \
# 0                                            1
# 1                                            0
#
#    calculated_host_listings_count_shared_rooms  reviews_per_month
# 0                                            0               0.01
# 1                                            0               0.37
#
# [2 rows x 106 columns]

# %%
lst.columns.tolist()
# Out:
# ['id',
#  'listing_url',
#  'scrape_id',
#  'last_scraped',
#  'name',
#  'summary',
#  'space',
#  'description',
#  'experiences_offered',
#  'neighborhood_overview',
#  'notes',
#  'transit',
#  'access',
#  'interaction',
#  'house_rules',
#  'thumbnail_url',
#  'medium_url',
#  'picture_url',
#  'xl_picture_url',
#  'host_id',
#  'host_url',
#  'host_name',
#  'host_since',
#  'host_location',
#  'host_about',
#  'host_response_time',
#  'host_response_rate',
#  'host_acceptance_rate',
#  'host_is_superhost',
#  'host_thumbnail_url',
#  'host_picture_url',
#  'host_neighbourhood',
#  'host_listings_count',
#  'host_total_listings_count',
#  'host_verifications',
#  'host_has_profile_pic',
#  'host_identity_verified',
#  'street',
#  'neighbourhood',
#  'neighbourhood_cleansed',
#  'neighbourhood_group_cleansed',
#  'city',
#  'state',
#  'zipcode',
#  'market',
#  'smart_location',
#  'country_code',
#  'country',
#  'latitude',
#  'longitude',
#  'is_location_exact',
#  'property_type',
#  'room_type',
#  'accommodates',
#  'bathrooms',
#  'bedrooms',
#  'beds',
#  'bed_type',
#  'amenities',
#  'square_feet',
#  'price',
#  'weekly_price',
#  'monthly_price',
#  'security_deposit',
#  'cleaning_fee',
#  'guests_included',
#  'extra_people',
#  'minimum_nights',
#  'maximum_nights',
#  'minimum_minimum_nights',
#  'maximum_minimum_nights',
#  'minimum_maximum_nights',
#  'maximum_maximum_nights',
#  'minimum_nights_avg_ntm',
#  'maximum_nights_avg_ntm',
#  'calendar_updated',
#  'has_availability',
#  'availability_30',
#  'availability_60',
#  'availability_90',
#  'availability_365',
#  'calendar_last_scraped',
#  'number_of_reviews',
#  'number_of_reviews_ltm',
#  'first_review',
#  'last_review',
#  'review_scores_rating',
#  'review_scores_accuracy',
#  'review_scores_cleanliness',
#  'review_scores_checkin',
#  'review_scores_communication',
#  'review_scores_location',
#  'review_scores_value',
#  'requires_license',
#  'license',
#  'jurisdiction_names',
#  'instant_bookable',
#  'is_business_travel_ready',
#  'cancellation_policy',
#  'require_guest_profile_picture',
#  'require_guest_phone_verification',
#  'calculated_host_listings_count',
#  'calculated_host_listings_count_entire_homes',
#  'calculated_host_listings_count_private_rooms',
#  'calculated_host_listings_count_shared_rooms',
#  'reviews_per_month']

# %% [markdown]
# ___________________________

# %% [markdown]
# Check this warning out:  DtypeWarning: Columns (61,62,94) have mixed types.

# %%
#lst.iloc[:, [61]]
#lst.iloc[:, [62]]
#lst.iloc[:, [94]]

# %% [markdown]
# Look more into the lst data

# %%
#lst.info()
lst.describe()
#lst.shape
# Out:
#                  id     scrape_id  thumbnail_url  medium_url  xl_picture_url  \
# count  4.858800e+04  4.858800e+04            0.0         0.0             0.0
# mean   2.306509e+07  2.020071e+13            NaN         NaN             NaN
# std    1.362972e+07  0.000000e+00            NaN         NaN             NaN
# min    2.060000e+03  2.020071e+13            NaN         NaN             NaN
# 25%    1.085637e+07  2.020071e+13            NaN         NaN             NaN
# 50%    2.236088e+07  2.020071e+13            NaN         NaN             NaN
# 75%    3.577099e+07  2.020071e+13            NaN         NaN             NaN
# max    4.410453e+07  2.020071e+13            NaN         NaN             NaN
#
#             host_id  host_listings_count  host_total_listings_count  \
# count  4.858800e+04         48576.000000               48576.000000
# mean   8.548647e+07            16.138710                  16.138710
# std    9.959082e+07           122.046309                 122.046309
# min    2.259000e+03             0.000000                   0.000000
# 25%    9.232804e+06             1.000000                   1.000000
# 50%    3.784629e+07             1.000000                   1.000000
# 75%    1.377744e+08             2.000000                   2.000000
# max    3.539906e+08          1834.000000                1834.000000
#
#            latitude     longitude  ...  review_scores_cleanliness  \
# count  48588.000000  48588.000000  ...               36247.000000
# mean      40.729365    -73.951143  ...                   9.269043
# std        0.054881      0.047500  ...                   1.128800
# min       40.499790    -74.240840  ...                   2.000000
# 25%       40.689920    -73.983380  ...                   9.000000
# 50%       40.724060    -73.955425  ...                  10.000000
# 75%       40.763023    -73.934430  ...                  10.000000
# max       40.911690    -73.712990  ...                  10.000000
#
#        review_scores_checkin  review_scores_communication  \
# count           36219.000000                 36238.000000
# mean                9.726470                     9.727413
# std                 0.790166                     0.819118
# min                 2.000000                     2.000000
# 25%                10.000000                    10.000000
# 50%                10.000000                    10.000000
# 75%                10.000000                    10.000000
# max                10.000000                    10.000000
#
#        review_scores_location  review_scores_value  \
# count            36215.000000         36216.000000
# mean                 9.592572             9.382069
# std                  0.791750             0.978356
# min                  2.000000             2.000000
# 25%                  9.000000             9.000000
# 50%                 10.000000            10.000000
# 75%                 10.000000            10.000000
# max                 10.000000            10.000000
#
#        calculated_host_listings_count  \
# count                    48588.000000
# mean                         5.917140
# std                         23.556815
# min                          1.000000
# 25%                          1.000000
# 50%                          1.000000
# 75%                          2.000000
# max                        261.000000
#
#        calculated_host_listings_count_entire_homes  \
# count                                 48588.000000
# mean                                      3.698053
# std                                      21.313062
# min                                       0.000000
# 25%                                       0.000000
# 50%                                       1.000000
# 75%                                       1.000000
# max                                     261.000000
#
#        calculated_host_listings_count_private_rooms  \
# count                                  48588.000000
# mean                                       2.020931
# std                                       10.265608
# min                                        0.000000
# 25%                                        0.000000
# 50%                                        0.000000
# 75%                                        1.000000
# max                                      148.000000
#
#        calculated_host_listings_count_shared_rooms  reviews_per_month
# count                                 48588.000000       37230.000000
# mean                                      0.095415           0.959229
# std                                       0.849292           1.304544
# min                                       0.000000           0.010000
# 25%                                       0.000000           0.140000
# 50%                                       0.000000           0.420000
# 75%                                       0.000000           1.320000
# max                                      24.000000          50.290000
#
# [8 rows x 42 columns]

# %%
hstlst = lst['host_listings_count']
hstlst.max()
# Out:
# 1834.0

# %% [markdown]
# ________

# %% [markdown]
# Start looking at visual representations of data

# %%
ax = sns.barplot(x = 'host_listings_count' , y = 'review_scores_value', data = lst, palette = ["red", "green", "blue"], ci = False)

# %%
plt.figure(figsize=(40,20))
pricexfeet = sns.barplot(x = 'price' , y = 'square_feet', data = lst, palette = ["red", "green", "blue"], ci = False)

# %% [markdown]
# Price is important in trying to solve my question, let's try to lock in on a price range.

# %%
price_range = pd.DataFrame(lst.groupby(['price']))
price_range
# Out:
#              0                                                  1
# 0        $0.00               id                            lis...
# 1    $1,000.00               id                            lis...
# 2    $1,001.00               id                            lis...
# 3    $1,002.00               id                            lis...
# 4    $1,020.00               id                            lis...
# ..         ...                                                ...
# 657    $980.00               id                            lis...
# 658    $985.00             id                           listin...
# 659     $99.00               id                            lis...
# 660    $995.00               id                            lis...
# 661    $999.00               id                            lis...
#
# [662 rows x 2 columns]

# %%
lst['price'] = lst['price'].str.replace('$', '')
lst['price'] = lst['price'].str.replace(',', '')
lst['price'] = lst['price'].astype(float)
lst.nlargest(100,['price'])['price']
# Out:
# 15160    10000.0
# 15206    10000.0
# 22449    10000.0
# 24396    10000.0
# 32240    10000.0
#           ...
# 3168      5250.0
# 16484     5000.0
# 19408     5000.0
# 21702     5000.0
# 21712     5000.0
# Name: price, Length: 100, dtype: float64

# %% [markdown]
# A suggestion:
# Get a count for listings per price, make a histogram so they are bunched(sns), make it a field - a new column categorized by range.
#
# Solution:
# Did not need to do this, as I found the a range that worked for me.

# %%
lst['price'].plot.line()

# %%
plt.figure(figsize=(60,20))
sns.distplot(lst['price'], bins=100, kde=False);

# %% [markdown]
# The graph above gave me my range of $0 - $2000. Now let me make a new df with this range.

# %%
##new dataframe using loc - from lst price less <= x. 
canbuy = lst.loc[(lst['price'] <= 2000)]
canbuy.head(2)
# Out:
#      id                        listing_url       scrape_id last_scraped  \
# 0  2060  https://www.airbnb.com/rooms/2060  20200707031313   2020-07-08
# 1  2595  https://www.airbnb.com/rooms/2595  20200707031313   2020-07-08
#
#                     name                                            summary  \
# 0             Modern NYC                                                NaN
# 1  Skylit Midtown Castle  Beautiful, spacious skylit studio in the heart...
#
#                                                space  \
# 0  Lovely, spacious, sunny 1 BR apartment in 6th ...
# 1  - Spacious (500+ft²), immaculate and nicely fu...
#
#                                          description experiences_offered  \
# 0  Lovely, spacious, sunny 1 BR apartment in 6th ...                none
# 1  Beautiful, spacious skylit studio in the heart...                none
#
#                                neighborhood_overview  ... instant_bookable  \
# 0                                                NaN  ...                f
# 1  Centrally located in the heart of Manhattan ju...  ...                f
#
#   is_business_travel_ready          cancellation_policy  \
# 0                        f                     flexible
# 1                        f  strict_14_with_grace_period
#
#   require_guest_profile_picture require_guest_phone_verification  \
# 0                             f                                f
# 1                             t                                t
#
#    calculated_host_listings_count  \
# 0                               1
# 1                               2
#
#    calculated_host_listings_count_entire_homes  \
# 0                                            0
# 1                                            2
#
#   calculated_host_listings_count_private_rooms  \
# 0                                            1
# 1                                            0
#
#    calculated_host_listings_count_shared_rooms  reviews_per_month
# 0                                            0               0.01
# 1                                            0               0.37
#
# [2 rows x 106 columns]

# %%
#hoodgroup = pd.DataFrame(canbuy.groupby('neighbourhood')['price'].count())

hoodgrpup = canbuy.groupby('neighbourhood').agg(count=('neighbourhood', 'size'), mean_sent=('price', 'mean')).reset_index()
hoodgroup
# Out:
#                  price
# neighbourhood
# Allerton             7
# Alphabet City      266
# Annadale             2
# Astoria            655
# Bath Beach          10
# ...                ...
# Williamsburg      1634
# Windsor Terrace     61
# Woodhaven           54
# Woodlawn             1
# Woodside            86
#
# [195 rows x 1 columns]

# %%
hoodgroups = canbuy.groupby('neighbourhood').agg(count=('neighbourhood', 'size'), mean_price=('price', 'mean')).reset_index()
hoodgroups
# Out:
#        neighbourhood  count  mean_price
# 0           Allerton      7   61.571429
# 1      Alphabet City    266  163.642857
# 2           Annadale      2  131.500000
# 3            Astoria    655  102.677863
# 4         Bath Beach     10  103.700000
# ..               ...    ...         ...
# 190     Williamsburg   1634  138.243574
# 191  Windsor Terrace     61  120.442623
# 192        Woodhaven     54   73.666667
# 193         Woodlawn      1  250.000000
# 194         Woodside     86   62.406977
#
# [195 rows x 3 columns]

# %% [markdown]
# Now to order it by count (for our graph)

# %%
tophood = hoodgroups[hoodgroups['count'] > 100 ].sort_values(by=['count'], ascending=False)
tophood
# Out:
#           neighbourhood  count  mean_price
# 18             Brooklyn  10773  120.830595
# 107           Manhattan  10182  181.401395
# 144              Queens   3095   92.523102
# 10   Bedford-Stuyvesant   1702  106.968273
# 190        Williamsburg   1634  138.243574
# 84               Harlem   1521  117.892834
# 117             Midtown   1495  220.084950
# 23             Bushwick    916   84.930131
# 179     Upper West Side    837  187.076464
# 178     Upper East Side    810  178.617284
# 54         East Village    738  182.695122
# 3               Astoria    655  102.677863
# 167           The Bronx    650   90.272308
# 44        Crown Heights    600  111.950000
# 106     Lower East Side    587  174.359455
# 28              Chelsea    548  212.640511
# 61             Flatbush    536   94.690299
# 85       Hell's Kitchen    521  196.642994
# 183  Washington Heights    416   93.728365
# 118        Midtown East    413  250.641646
# 94              Jamaica    398   98.075377
# 78           Greenpoint    380  133.023684
# 52          East Harlem    358  117.787709
# 185        West Village    357  241.226891
# 34         Clinton Hill    336  140.750000
# 60   Financial District    334  188.955090
# 83     Hamilton Heights    288   95.277778
# 136          Park Slope    283  170.194346
# 1         Alphabet City    266  163.642857
# 99             Kips Bay    261  207.118774
# 29            Chinatown    259  187.586873
# 164       Staten Island    205   97.219512
# 168       The Rockaways    197  172.131980
# 67          Fort Greene    193  161.818653
# 165           Sunnyside    192   90.177083
# 51        East Flatbush    188   97.079787
# 149           Ridgewood    186   82.962366
# 53        East New York    181   88.845304
# 64             Flushing    163  109.975460
# 100     Lefferts Garden    155  113.161290
# 166         Sunset Park    145   79.910345
# 156                Soho    137  250.496350
# 80    Greenwich Village    129  208.224806
# 62    Flatiron District    122  296.622951
# 6             Bay Ridge    120  104.091667
# 126         Murray Hill    113  198.203540
# 24             Canarsie    113  110.805310
# 93      Jackson Heights    110   76.609091
# 104    Long Island City    107  132.579439
# 58             Elmhurst    106   67.707547
# 132              Nolita    106  225.009434
# 175             Tribeca    105  286.914286
# 143    Prospect Heights    104  153.538462
# 14          Boerum Hill    102  182.000000

# %%
plt.figure(figsize=(10,5))
hoodcount = sns.barplot(x = 'neighbourhood' , y = 'count', data = tophood, palette = ["red", "green", "blue"], ci = False)

# %% [markdown]
# Drop the bouroughs, then graph the neighborhoods and the amount of listings they have.

# %%
#th = tophood.drop(['Brooklyn', 'Manhattan', 'The Bronx'])
th = tophood.drop([18, 107, 144, 164, 167])

plt.figure(figsize=(10,10))
hoodscount = sns.barplot(x = 'count' , y = 'neighbourhood', data = th, palette = ["red", "green", "blue"],  ci = False)

# %% [markdown]
# Grab all the data from our original df, that matches our new neighborhood and price list.

# %%
#canbuy where neighborhood in th
okay = canbuy[canbuy['neighbourhood'].isin(th['neighbourhood'])]
okay
# Out:
#              id                            listing_url       scrape_id  \
# 0          2060      https://www.airbnb.com/rooms/2060  20200707031313
# 4          5099      https://www.airbnb.com/rooms/5099  20200707031313
# 8          5203      https://www.airbnb.com/rooms/5203  20200707031313
# 9          5238      https://www.airbnb.com/rooms/5238  20200707031313
# 11         5803      https://www.airbnb.com/rooms/5803  20200707031313
# ...         ...                                    ...             ...
# 48564  44088976  https://www.airbnb.com/rooms/44088976  20200707031313
# 48565  44089440  https://www.airbnb.com/rooms/44089440  20200707031313
# 48568  44097382  https://www.airbnb.com/rooms/44097382  20200707031313
# 48575  44100164  https://www.airbnb.com/rooms/44100164  20200707031313
# 48576  44100276  https://www.airbnb.com/rooms/44100276  20200707031313
#
#       last_scraped                                               name  \
# 0       2020-07-08                                         Modern NYC
# 4       2020-07-07          Large Cozy 1 BR Apartment In Midtown East
# 8       2020-07-07                 Cozy Clean Guest Room - Family Apt
# 9       2020-07-08                 Cute & Cozy Lower East Side 1 bdrm
# 11      2020-07-08     Lovely Room 1, Garden, Best Area, Legal rental
# ...            ...                                                ...
# 48564   2020-07-08                      Spacious work-from-home oasis
# 48565   2020-07-08         Charming 2 bedroom in the heart of Astoria
# 48568   2020-07-07               Get Inspired in SOHO - 1BR Apartment
# 48575   2020-07-08   Modern, luxurious apt in NYC w/ private terrace!
# 48576   2020-07-07  Sleek East Village 1BR w/ Gym, Doorman, Garden...
#
#                                                  summary  \
# 0                                                    NaN
# 4      My large 1 bedroom apartment has a true New Yo...
# 8      Our best guests are seeking a safe, clean, spa...
# 9      Live like a New Yorker instead of a stuffy, ti...
# 11     Discounted now!   Beautiful house, gorgeous ga...
# ...                                                  ...
# 48564  The ultimate work-from-home oasis. Newly renov...
# 48565  Our charming 2-bedroom is perfect for your sta...
# 48568  This lovely 1BR apartment is located in prime ...
# 48575  Amazing, luxurious and modern 1 bedroom apt wi...
# 48576  Show up and start living from day one in New Y...
#
#                                                    space  \
# 0      Lovely, spacious, sunny 1 BR apartment in 6th ...
# 4      I have a large 1 bedroom apartment centrally l...
# 8      Stay in my family's little  guest room and enj...
# 9      PLEASE NOTE: do not automatically book with ou...
# 11     Welcome to an historic, stunning 4-story Brook...
# ...                                                  ...
# 48564  Duplex condo apartment - garden level and firs...
# 48565  The second bedroom is currently styled as a ho...
# 48568                                                NaN
# 48575  The space the layout of the apartment is: - Br...
# 48576  Thoughtfully designed with bespoke finishes, m...
#
#                                              description experiences_offered  \
# 0      Lovely, spacious, sunny 1 BR apartment in 6th ...                none
# 4      My large 1 bedroom apartment has a true New Yo...                none
# 8      Our best guests are seeking a safe, clean, spa...                none
# 9      Live like a New Yorker instead of a stuffy, ti...                none
# 11     Discounted now!   Beautiful house, gorgeous ga...                none
# ...                                                  ...                 ...
# 48564  The ultimate work-from-home oasis. Newly renov...                none
# 48565  Our charming 2-bedroom is perfect for your sta...                none
# 48568  This lovely 1BR apartment is located in prime ...                none
# 48575  Amazing, luxurious and modern 1 bedroom apt wi...                none
# 48576  Show up and start living from day one in New Y...                none
#
#                                    neighborhood_overview  ...  \
# 0                                                    NaN  ...
# 4      My neighborhood in Midtown East is called Murr...  ...
# 8      Our neighborhood is full of restaurants and ca...  ...
# 9      Historically, the Lower East Side was a stoppi...  ...
# 11     Neighborhood is amazing! Best subways to Manha...  ...
# ...                                                  ...  ...
# 48564  Clinton Hill - the heart of brownstone Brookly...  ...
# 48565  Astoria, named the #1 coolest neighborhood in ...  ...
# 48568                                                NaN  ...
# 48575                                                NaN  ...
# 48576  This rental is located in NYC’s East Village. ...  ...
#
#       instant_bookable is_business_travel_ready          cancellation_policy  \
# 0                    f                        f                     flexible
# 4                    f                        f                     moderate
# 8                    f                        f                     flexible
# 9                    f                        f  strict_14_with_grace_period
# 11                   f                        f  strict_14_with_grace_period
# ...                ...                      ...                          ...
# 48564                f                        f                     flexible
# 48565                t                        f                     flexible
# 48568                t                        f                     flexible
# 48575                t                        f                     flexible
# 48576                t                        f                     flexible
#
#       require_guest_profile_picture require_guest_phone_verification  \
# 0                                 f                                f
# 4                                 t                                t
# 8                                 t                                t
# 9                                 f                                f
# 11                                t                                f
# ...                             ...                              ...
# 48564                             f                                f
# 48565                             f                                f
# 48568                             f                                f
# 48575                             f                                f
# 48576                             f                                f
#
#        calculated_host_listings_count  \
# 0                                   1
# 4                                   1
# 8                                   1
# 9                                   4
# 11                                  3
# ...                               ...
# 48564                               1
# 48565                               1
# 48568                               1
# 48575                               1
# 48576                             261
#
#        calculated_host_listings_count_entire_homes  \
# 0                                                0
# 4                                                1
# 8                                                0
# 9                                                2
# 11                                               1
# ...                                            ...
# 48564                                            1
# 48565                                            1
# 48568                                            1
# 48575                                            1
# 48576                                          261
#
#       calculated_host_listings_count_private_rooms  \
# 0                                                1
# 4                                                0
# 8                                                1
# 9                                                0
# 11                                               2
# ...                                            ...
# 48564                                            0
# 48565                                            0
# 48568                                            0
# 48575                                            0
# 48576                                            0
#
#        calculated_host_listings_count_shared_rooms  reviews_per_month
# 0                                                0               0.01
# 4                                                0               0.57
# 8                                                0               0.89
# 9                                                2               1.22
# 11                                               0               1.32
# ...                                            ...                ...
# 48564                                            0                NaN
# 48565                                            0                NaN
# 48568                                            0                NaN
# 48575                                            0                NaN
# 48576                                            0                NaN
#
# [20523 rows x 106 columns]

# %% [markdown]
# Add the 2 other columns from our th(tophood) df. The columns are count and mean_price and we match them to neighborhood.
